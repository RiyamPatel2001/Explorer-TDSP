# %% [markdown]
# # 🚗 **Welcome to the <font color='crimson'>** **Explorer Transportation Data Science Project! 🚗**</font>
#  Hosted by the [Northeast Big Data Innovation Hub](https://nebigdatahub.org/about) & [National Student Data Corps](https://nebigdatahub.org/nsdc), in collaboration with the [U.S. Department of Transportation Federal Highway Administration](https://highways.dot.gov/).
#
#
# ---

# %% [markdown]
# ## <font color='crimson'>**Project Information and Background:**</font>

# %% [markdown]
# **Project Description:**
#
# By participating in this project, you are joining a
# community of transportation data science learners interested in making roads safer for vulnerable road users.
#
# The Explorer TDSP has six Milestones, including guided transportation research into a community of interest. Each Milestone can take 1-5 hours, or less, depending on your level of experience.
#
# To learn more about this project, including key highlights, incentives, and important links, [review the TDSP Webpage here](https://nebigdatahub.org/nsdc/tdsp/)!

# %% [markdown]
# ## <font color='crimson'>**How to Get Started:**</font>

# %% [markdown]
# In order to work within this Google Colab Notebook, **please start by clicking on "File" in the top left corner of your notebook, and then "Save a copy in Drive." Rename the file to "Explorer TDSP - Your Full Name."** This will save a copy of the notebook in your personal Google Drive.
#
# You may now begin!

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## <font color='crimson'>**A Quick Introduction to Google Colab**</font>

# %% [markdown]
# Read below for a Google Colab QuickStart:
# - Google Colab is a Python Notebook environment built by Google that's free for all.
# - Colab Notebooks are made up of cells; cells can be either *text* or *code* cells. You can click the +code or +text button at the top of the Notebook to create a new cell.
# - Text cells use a format called [Markdown](https://www.markdownguide.org/getting-started/). Knowledge of Markdown is not required for this project. However, if you'd like to learn more, [check out this Cheatsheet!](https://www.markdownguide.org/cheat-sheet/)
# - Python code is executed in *code* cells. When you want to run your code, hover your cursor over the square brackets in the top left corner of your code cell. You'll notice a play button pop up! (▶) Click the play button to run the code in that cell. Code cells run one at a time.
# - The memory shared across your notebook is called the *Runtime*. You can think of a Runtime as a "code session" where everything you create and execute is temporarily stored.
# - Runtimes will persist for a short period of time, so you are safe if you need to refresh the page, but Google will shutdown a Runtime after enough time has passed. Everything that you have printed out will remain within your Notebook even if the runtime is disconnected.
#
# If this is your first time using Google Colab, we highly recommend reviewing the [NSDC's *Using Google Colab Guide*](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf) before continuing. For a more comprehensive guide, see [Colab's *Welcome To Colaboratory* walkthrough.](https://colab.research.google.com/github/prites18/NoteNote/blob/master/Welcome_To_Colaboratory.ipynb)

# %% [markdown]
# ## <font color='crimson'>**An Introduction to Python Programming**</font>

# %% [markdown]
# Python is a programming language often used to analyze data.
#
# Python is open-source, which means it's free to use and distribute, even for commercial purposes. Python's versatility allows it to be used for web development, data visualization, artificial intelligence, scientific computing, and more.
#
# Python's extensive standard library, along with its powerful third-party packages, enable developers and data scientists to perform a vast array of tasks.
#
# For those looking to dive deeper into Python, here are some valuable resources:
# - [The Official Python Documentation](https://docs.python.org/3/) – Offers comprehensive guides and reference materials for Python leaners.
# - [Real Python](https://realpython.com/) – Provides tutorials and articles for Python developers of all skill levels.
# - [PyCon](https://pycon.org/) – The largest annual gathering for the Python community, which is useful for learning from experts and discovering the latest developments in the Python ecosystem.
# - [Python for Everybody](https://www.py4e.com/) – A book and website by Dr. Charles Severance that offers a free course on Python for beginners.

# %% [markdown]
# **Let's review some essential Python Functions!**
#
# Here are some key functions you'll frequently encounter:
#
# 1. **`head()`**: This function is crucial for getting a quick overview of your dataset. By default, it returns the first five rows, offering a snapshot of your data's structure and values.
#
# 2. **`describe()`**: This provides a summary of the statistical characteristics of your dataset. It's particularly useful for gaining insights into the distribution, mean, standard deviation, and range of numerical columns.
#
# 3. **`sum()`**: This calculates the total sum of a column or a series of numbers, proving essential for quick calculations and aggregations in data analysis.
#
# 4. **`isnull()`**: This helps identify missing or null values in your dataset, allowing for effective data cleaning and preprocessing.
#
# 5. **`value_counts()`**: Understanding the frequency of various values in your dataset is a common task in data science. The `value_counts()` function makes this easy by counting the occurrence of each unique value in a column.
#
# Now that you've reviewed these important concepts, let's dive in to the project!

# %% [markdown]
# ## <font color='crimson'>**Milestone #1 - Data Preparation**</font>
# GOAL: The main goal of this milestone is to set up your environment, install the required packages, learn how to access data and do some basic exploratory data analysis.

# %% [markdown]
# **Step 1:** Setting up libraries and installing packages
#
# A **library** is a collection of code that you can use in your programs, while a **package** is a folder that contains libraries or other packages, organized for easy use.
#
# To install a library, we'll use the following format:
# ```python
#  import <library name> as <shortname>
# ```
# We use a *short name* since it is easier to refer to the package to access functions and also to refer to subpackages within the library. Think of it as a nickname for easier reference!

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium

# %% [markdown]
# These are the libraries that will help us throughout this project. We invite you to research each library for a better understanding.
#
# We encourage you to read more about the important and most commonly used libraries like Pandas, Matplotlib, and Seaborn and write a few lines in your own words about what they do. [You may use the Data Science Resource Repository (DSRR) to find resources to get started!](https://nebigdatahub.org/nsdc/data-science-resource-repository/)

# %% [markdown]
# **TO DO:** Write a few lines about what each library does:
#
#
#
#
# > * Pandas: Pandas is a python library for data manipulation and analysis. It offers data structures and operations for manipulating numerical tables and time series.
#
# > * Matplotlib: Matplotlib is a powerful and versatile open-source plotting library for Python, designed to help users visualize data in a variety of formats. It lets us convert boring data into interactive plots and graphs. It enables users to graphically represent data, facilitating easier analysis and understanding.
#
# > * Seaborn: Seaborn is a visualization library for statistical graphics plotting in Python. It provides beautiful default styles and color palettes to make statistical plots more attractive. It is built on top matplotlib library and is also closely integrated with the data structures from pandas.

# %% [markdown]
# **Step 2:** Let’s access our data. We will be using the [NYC OpenData Motor Vehicle Collisions - Crashes dataset](https://data.cityofnewyork.us/Public-Safety/Motor-Vehicle-Collisions-Crashes/h9gi-nx95). According to NYC Open Data, "each row represents a crash event. The Motor Vehicle Collisions data tables contain information from all police reported motor vehicle collisions in NYC." If you need a reminder on how to upload your dataset, [please review helpful hints here.](https://nebigdatahub.org/wp-content/uploads/2023/04/NSDC-Data-Science-Projects-Introduction-Using-Google-Colab.pdf)
#
# Since this is a large dataset, we highly recommend that you upload your data by [mounting your Google Drive](https://colab.research.google.com/notebooks/io.ipynb#scrollTo=u22w3BFiOveA).
#
# To mount your Google Drive, begin by finding the folder icon on the left side of your screen. When you click on this folder icon, you will open the Files window. Click on the icon at the top of the Files window that says "Mount Drive" as you hover over it.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Next, we will read the data using the `pd.read_csv` function.
# Ensure that you've downloaded the dataset from NYC OpenData, and uploaded the dataset to your Google Drive.

# %%
# Define the path to where we want to store the csv file
csv_file_path = "/content/drive/MyDrive/Colab Notebooks/Datasets/Motor_Vehicle_Collisions_-_Crashes_20250108.csv"
# Load the csv file into a dataframe using pd.read_csv
data = pd.read_csv(csv_file_path)
# Out:
# <ipython-input-4-5be01e591ac9>:4: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(csv_file_path)

# %% [markdown]
# Hint: Your data's file path describes the location of where your data lives. To locate your data's file path, click on the folder/file-shaped icon on the left side of the Notebook. You'll notice a folder labeled "drive." Search for your Motor Vehicle Collisions Dataset within that folder. Right click on your Dataset to "copy path." Paste that path below.

# %% [markdown]
# **Step 3:** Let's see what the data looks like. We can use the `head` function which returns the first 5 rows of the dataset.

# %%
# TODO: Print the first 5 rows of the data using head function of pandas
data.head()
# Out:
#    CRASH DATE CRASH TIME   BOROUGH ZIP CODE   LATITUDE  LONGITUDE  \
# 0  09/11/2021       2:39       NaN      NaN        NaN        NaN
# 1  03/26/2022      11:45       NaN      NaN        NaN        NaN
# 2  06/29/2022       6:55       NaN      NaN        NaN        NaN
# 3  09/11/2021       9:35  BROOKLYN  11208.0  40.667202 -73.866500
# 4  12/14/2021       8:13  BROOKLYN  11233.0  40.683304 -73.917274
#
#                   LOCATION           ON STREET NAME CROSS STREET NAME  \
# 0                      NaN    WHITESTONE EXPRESSWAY         20 AVENUE
# 1                      NaN  QUEENSBORO BRIDGE UPPER               NaN
# 2                      NaN       THROGS NECK BRIDGE               NaN
# 3    (40.667202, -73.8665)                      NaN               NaN
# 4  (40.683304, -73.917274)          SARATOGA AVENUE    DECATUR STREET
#
#            OFF STREET NAME  ...  CONTRIBUTING FACTOR VEHICLE 2  \
# 0                      NaN  ...                    Unspecified
# 1                      NaN  ...                            NaN
# 2                      NaN  ...                    Unspecified
# 3  1211      LORING AVENUE  ...                            NaN
# 4                      NaN  ...                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 3  CONTRIBUTING FACTOR VEHICLE 4  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#    CONTRIBUTING FACTOR VEHICLE 5  COLLISION_ID  VEHICLE TYPE CODE 1  \
# 0                            NaN       4455765                Sedan
# 1                            NaN       4513547                Sedan
# 2                            NaN       4541903                Sedan
# 3                            NaN       4456314                Sedan
# 4                            NaN       4486609                  NaN
#
#    VEHICLE TYPE CODE 2  VEHICLE TYPE CODE 3 VEHICLE TYPE CODE 4  \
# 0                Sedan                  NaN                 NaN
# 1                  NaN                  NaN                 NaN
# 2        Pick-up Truck                  NaN                 NaN
# 3                  NaN                  NaN                 NaN
# 4                  NaN                  NaN                 NaN
#
#   VEHICLE TYPE CODE 5
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#
# [5 rows x 29 columns]

# %%
# TODO: Describe the data using the describe function of pandas
desc_stats = data.describe()
desc_stats
# Out:
#            LATITUDE     LONGITUDE  NUMBER OF PERSONS INJURED  \
# count  1.907888e+06  1.907888e+06               2.147422e+06
# mean   4.062023e+01 -7.373853e+01               3.195576e-01
# std    2.054513e+00  3.848699e+00               7.080539e-01
# min    0.000000e+00 -2.013600e+02               0.000000e+00
# 25%    4.066755e+01 -7.397469e+01               0.000000e+00
# 50%    4.072055e+01 -7.392705e+01               0.000000e+00
# 75%    4.076962e+01 -7.386673e+01               0.000000e+00
# max    4.334444e+01  0.000000e+00               4.300000e+01
#
#        NUMBER OF PERSONS KILLED  NUMBER OF PEDESTRIANS INJURED  \
# count              2.147409e+06                   2.147440e+06
# mean               1.541858e-03                   5.813015e-02
# std                4.144117e-02                   2.472256e-01
# min                0.000000e+00                   0.000000e+00
# 25%                0.000000e+00                   0.000000e+00
# 50%                0.000000e+00                   0.000000e+00
# 75%                0.000000e+00                   0.000000e+00
# max                8.000000e+00                   2.700000e+01
#
#        NUMBER OF PEDESTRIANS KILLED  NUMBER OF CYCLIST INJURED  \
# count                  2.147440e+06               2.147440e+06
# mean                   7.623030e-04               2.795980e-02
# std                    2.816714e-02               1.669935e-01
# min                    0.000000e+00               0.000000e+00
# 25%                    0.000000e+00               0.000000e+00
# 50%                    0.000000e+00               0.000000e+00
# 75%                    0.000000e+00               0.000000e+00
# max                    6.000000e+00               4.000000e+00
#
#        NUMBER OF CYCLIST KILLED  NUMBER OF MOTORIST INJURED  \
# count              2.147440e+06                2.147440e+06
# mean               1.206087e-04                2.292502e-01
# std                1.102386e-02                6.692077e-01
# min                0.000000e+00                0.000000e+00
# 25%                0.000000e+00                0.000000e+00
# 50%                0.000000e+00                0.000000e+00
# 75%                0.000000e+00                0.000000e+00
# max                2.000000e+00                4.300000e+01
#
#        NUMBER OF MOTORIST KILLED  COLLISION_ID
# count               2.147440e+06  2.147440e+06
# mean                6.342436e-04  3.212892e+06
# std                 2.754345e-02  1.507079e+06
# min                 0.000000e+00  2.200000e+01
# 25%                 0.000000e+00  3.172980e+06
# 50%                 0.000000e+00  3.709986e+06
# 75%                 0.000000e+00  4.247076e+06
# max                 5.000000e+00  4.784196e+06

# %%
data.columns
# Out:
# Index(['CRASH DATE', 'CRASH TIME', 'BOROUGH', 'ZIP CODE', 'LATITUDE',
#        'LONGITUDE', 'LOCATION', 'ON STREET NAME', 'CROSS STREET NAME',
#        'OFF STREET NAME', 'NUMBER OF PERSONS INJURED',
#        'NUMBER OF PERSONS KILLED', 'NUMBER OF PEDESTRIANS INJURED',
#        'NUMBER OF PEDESTRIANS KILLED', 'NUMBER OF CYCLIST INJURED',
#        'NUMBER OF CYCLIST KILLED', 'NUMBER OF MOTORIST INJURED',
#        'NUMBER OF MOTORIST KILLED', 'CONTRIBUTING FACTOR VEHICLE 1',
#        'CONTRIBUTING FACTOR VEHICLE 2', 'CONTRIBUTING FACTOR VEHICLE 3',
#        'CONTRIBUTING FACTOR VEHICLE 4', 'CONTRIBUTING FACTOR VEHICLE 5',
#        'COLLISION_ID', 'VEHICLE TYPE CODE 1', 'VEHICLE TYPE CODE 2',
#        'VEHICLE TYPE CODE 3', 'VEHICLE TYPE CODE 4', 'VEHICLE TYPE CODE 5'],
#       dtype='object')

# %% [markdown]
# The information above is currently formatted in scientific notation. Need a refresher? [Review how to analyze and convert to and from scientific notation here!](https://www.mathsisfun.com/numbers/scientific-notation.html)
#
# 1. Latitude & Longitude: The latitude and longitude indicate where the crashes are occurring. However, there are some data points with latitude and longitude values of 0, which is likely due to missing or inaccurate data.
#
# 2. Number of Persons Injured: On average, each crash has around 0.305 injuries. The maximum number of injuries in a single crash is 43.
#
# 3. Number of Persons Killed: Fatalities are rare, with an average of 0.00146 deaths per crash. The maximum number of deaths in one crash is 8.
#
# 4. Number of Pedestrians, Cyclists, and Motorists Injured/Killed: These columns provide a breakdown of the injuries and fatalities by type of individual involved.
#
# 5. Collision ID: This is a unique identifier for each crash.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #2 - Data Ethics, Pre-Processing, and Exploration** </font>
# GOAL: The main goal of this milestone is to assess the dataset, find missing values, and decide what to do with those missing data points.

# %% [markdown]
# **Step 1:**
# Before we begin assessing our data for missing values, it is important that we understand the ethical implications surrounding data processing. To best prepare yourself for this module, review one or more of the following resources:
# - [Data Science Ethics Flashcard Video Series](https://youtube.com/playlist?list=PLNs9ZO9jGtUB7XTjXy-ttoo2QSLld9SrV&feature=shared)
# - [What Do I Need to Understand about Data Ethics?](https://www.youtube.com/watch?v=Efy8htCDueE)
# -[Introduction to Data Cleaning](https://www.youtube.com/watch?v=t8WkoGLkdTk)
#
# **TO DO:** Based on the resources above and outside knowledge, what are some potential bias issues related to the availability of data from well-resourced communities as compared to under-resourced communities? How might bias show up in our dataset?
#
# > Answer here:
#
# > Data from well-resourced communities might be more readily available and comprehensive due to better infrastructure, technology, and resources for data collection and reporting. In contrast, under-resourced communities may lack the capacity for thorough data collection, leading to incomplete or missing data. This discrepancy can result in a biased dataset where the experiences and needs of under-resourced communities are underrepresented or inaccurately captured.
#
# > In our dataset, this bias could manifest as an undercount of crashes in under-resourced areas, potentially leading to skewed analyses and ineffective resource allocation. For example, if a certain area lacks proper reporting mechanisms, the crash data may not be as complete, leading to inaccurate conclusions about the overall safety of various communities. This can result in a misrepresentation of the true picture of traffic safety.

# %% [markdown]
# **Step 2:**
# Check the dataset for missing values.

# %%
#TODO: Leverage the isnull() and sum() functions to find the number of missing values in each column
missing_values = data.isnull().sum()

#TODO: Turn the missing value counts into percentages
missing_values_percentage = (missing_values / len(data)) * 100
#TODO: Return counts and percentages of missing values in each column
missing_data = pd.DataFrame({'Missing Values': missing_values, 'Percentage (%)': missing_values_percentage})
missing_data.sort_values(by='Percentage (%)', ascending=False)
# Out:
#                                Missing Values  Percentage (%)
# VEHICLE TYPE CODE 5                   2138129       99.566414
# CONTRIBUTING FACTOR VEHICLE 5         2137833       99.552630
# VEHICLE TYPE CODE 4                   2113524       98.420631
# CONTRIBUTING FACTOR VEHICLE 4         2112264       98.361957
# VEHICLE TYPE CODE 3                   1998606       93.069236
# CONTRIBUTING FACTOR VEHICLE 3         1992780       92.797936
# OFF STREET NAME                       1778642       82.826156
# CROSS STREET NAME                      818761       38.127305
# ZIP CODE                               665959       31.011763
# BOROUGH                                665696       30.999516
# ON STREET NAME                         461171       21.475385
# VEHICLE TYPE CODE 2                    420764       19.593749
# CONTRIBUTING FACTOR VEHICLE 2          338763       15.775202
# LOCATION                               239552       11.155236
# LONGITUDE                              239552       11.155236
# LATITUDE                               239552       11.155236
# VEHICLE TYPE CODE 1                     14916        0.694594
# CONTRIBUTING FACTOR VEHICLE 1            7302        0.340033
# NUMBER OF PERSONS KILLED                   31        0.001444
# NUMBER OF PERSONS INJURED                  18        0.000838
# COLLISION_ID                                0        0.000000
# CRASH DATE                                  0        0.000000
# NUMBER OF MOTORIST KILLED                   0        0.000000
# NUMBER OF MOTORIST INJURED                  0        0.000000
# NUMBER OF CYCLIST KILLED                    0        0.000000
# CRASH TIME                                  0        0.000000
# NUMBER OF PEDESTRIANS KILLED                0        0.000000
# NUMBER OF PEDESTRIANS INJURED               0        0.000000
# NUMBER OF CYCLIST INJURED                   0        0.000000

# %% [markdown]
# Here's an overview of the missing values in the dataset:
#
# Columns like VEHICLE TYPE CODE 5, CONTRIBUTING FACTOR VEHICLE 5, VEHICLE TYPE CODE 4, and so on have a high percentage of missing values. This is expected since not all crashes involve multiple vehicles or factors.
#
# OFF STREET NAME and CROSS STREET NAME have significant missing values. This could be due to crashes occurring in locations where these details aren't applicable or weren't recorded.
#
# ZIP CODE, BOROUGH, and ON STREET NAME also have missing values. This might be due to incomplete data entry or crashes occurring in areas where these specifics aren't easily determinable.
#
# LOCATION, LATITUDE, and LONGITUDE have the same count of missing values, indicating that when one is missing, the others are likely missing as well.

# %% [markdown]
# **Step 3:** Create a bar chart to display the top 10 contributing factors (e.g. backing up unsafely, unsafe lane changing, etc.) to crashes within the dataset.

# %%
#TODO: Plot a Bar Chart

top_factors = data['CONTRIBUTING FACTOR VEHICLE 1'].value_counts().head(10)


plt.figure(figsize=(12, 7))
# TODO: Plotting the top contributing factors, fill in x as the index field of the variable 'top_factors'
sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")
plt.title('Top 10 Contributing Factors to crashes', fontsize=16)
plt.xlabel('Top factors', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-9-fd7b3c9f3edc>:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_factors.index, y=top_factors.values, palette="magma")

# %% [markdown]
# **TO DO:** Besides for "Unspecified," what are the top 3 contributing factors that cause the most crashes?
#
# > *  Driver Inattention/ Distraction
# > *  Failure to Yield Right-of-Way
# > *  Following Too Closely

# %% [markdown]
# **TO DO:** What recommendations would you make to new and current drivers after assessing the above data?
#
# > *   Avoid Distractions: The data shows that "Driver Inattention/Distraction" is a leading cause of crashes. It's crucial to avoid using cell phones or engaging in other distracting activities while driving.
#
# >* Yield Right-of-Way: "Failure to Yield Right-of-Way" is another significant contributing factor. Drivers should always be aware of traffic laws and who has the right-of-way at intersections and other traffic situations.
#
# >* Maintain Safe Following Distance: "Following Too Closely" is a common cause of accidents. Drivers should maintain a safe distance from the vehicle ahead to allow sufficient time to react to sudden stops or changes in traffic conditions.

# %% [markdown]
# **Step 4:** Now, let's create another bar chart to determine which vehicle types were involved in the most crashes.

# %%
# Determine the top vehicle types involved in crashes
top_vehicle_types = data['VEHICLE TYPE CODE 1'].value_counts().head(10)

# Plotting the top vehicle types
plt.figure(figsize=(12, 7))
sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")
plt.title('Top 10 Vehicle Types Involved in crashes', fontsize=16)
plt.xlabel('Vehicle Type', fontsize=14)
plt.ylabel('Number of crashes', fontsize=14)
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-10-d81efa66963e>:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_vehicle_types.index, y=top_vehicle_types.values, palette="cividis")

# %% [markdown]
# **TO DO:** What are the top 3 vehicles that were most involved in crashes?
#
#
# > *   Sedan
# > *   Staion Wagon/ Sport Utility Vehicle
# > *   Passenger Vehicle

# %% [markdown]
# **TO DO:** Why do you think that "Sedan[s]," "Station Wagon[s]," and "Passenger Vehicle[s]" are involved in a larger number of crashes, injuries, and deaths when compared to the rest of the vehicles? (Think outside the box!)
#
#
# > *  **Higher Prevalence**: Sedans, station wagons, and passenger vehicles are extremely common on the road. Their sheer number increases the likelihood of them being involved in a crash. The more of these vehicles there are, the more opportunities they have to be involved in an accident.
#
# >* **General Use**: These types of vehicles are used for daily commutes, errands, and family trips, making them more exposed to a variety of driving conditions and traffic situations. This constant use increases their chances of being in an accident compared to less frequently used vehicles.
#
# >* **Driver Demographics**: These vehicles tend to be driven by a wider range of drivers with varying levels of experience, which might contribute to a higher crash rate compared to other vehicle types with more specialized drivers.
#
# >* **Safety vs. Size**: Compared to larger vehicles like SUVs or trucks, sedans and station wagons are often lighter, which means they absorb less energy in a crash. This can lead to greater injuries for occupants.
#
# >* **Mismatched Collisions**: In collisions with larger vehicles like SUVs or trucks, occupants of sedans are more likely to sustain severe injuries. This is because the laws of physics dictate that in a crash between mismatched vehicles, the lighter one takes the brunt of the impact.
#
# >* **Vehicle Design**: The design of the vehicle may also play a role. Some older or smaller sedans may lack modern safety features, making them more vulnerable in a crash.

# %% [markdown]
# **TO DO:** Review the x-axis of the bar chart you created above. </br>
# 1) What do you notice? </br>
# 2) What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why? </br>
# 3) What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
#
# <br>
#
# >What do you notice?
#
# >Looking at the x-axis of the bar chart displaying vehicle types, the labels are inconsistent, and some are difficult to interpret.
#
# >Here's what stands out:
#
# >**Inconsistency**: There is a mix of abbreviations ("PK"), and some vehicle types are in full words ("Sedan", "Station Wagon", etc).
#
# >**Lack of Clarity**: Some vehicle types are vague ("PASSENGER VEHICLE") or may not be easily understood by all viewers.
#
# >**Potential for Grouping**: Some labels might be very similar, and it may make more sense to group them (e.g., "SPORT UTILITY/STATION WAGON").
#
# >**Typos**: There may also be typos and inconsistencies in capitalization (e.g., 'PICK UP TRUCK' and 'PICK-UP TRUCK')
#
# </br>
#
# <br>
#
# >What would you recommend we do to improve the bar chart, based on the x-axis (horizontal axis) and why?
#
# >To improve the x-axis, I recommend the following:
#
# >Standardize Labels: Ensure all vehicle types have clear, consistent labels. Instead of "PK," use "Pick-up Truck" or similar.
# Use Full, Descriptive Names: Avoid vague labels. Instead of "PASSENGER VEHICLE," use "Passenger Car" or a similar term.
#
# >Group Similar Categories: Combine similar categories into broader groups. For example, combine "SPORT UTILITY VEHICLE" and "STATION WAGON" into "SUV/Station Wagon." This can reduce clutter and make the chart easier to read.
#
# >Proper Capitalization: Capitalize consistently (e.g., "Pick-Up Truck" instead of "PICK UP TRUCK")
#
# >Rotate Labels: If needed, rotate labels to avoid overlap
#
# >These changes would make the x-axis more readable, easily understandable, and less cluttered, which would help people understand the graph more effectively.
#
# </br>
#
# <br>
#
# >What recommendation would you make to those who are collecting and/or inputting data into this dataset?
#
# >For those collecting and inputting data, I'd make the following recommendations:
#
# >Use Standardized Drop-Down Menus: When collecting data, use a standardized drop-down menu with pre-defined, consistent categories. This ensures uniformity and reduces the chances of misspelled or ambiguous entries.
#
# >Data Dictionary: Create a data dictionary that defines each category and data entry, so people can ensure that they are consistent when inputting data into the dataset.
#
# >Data Cleaning: Implement data validation checks to flag inconsistent or unclear entries when inputting data, prompting correction at the point of entry.
#
# >Periodic Data Cleanup: Regularly review and clean the data, standardizing entries and correcting any inconsistencies or typos. This can be achieved by running scripts or building functions in Python or R.
#
# >Training: Provide training to those collecting data on the importance of accurate and consistent entries, and how to use dropdown menus when inputting the data.
#
# </br>
#
#
# <br>
#
# > There is one more thing, the dataset i highly imbalanced. This also needs to be taken into consideration.
#
# </br>

# %% [markdown]
# **Step 5:**  A DataFrame is a two-dimensional and potentially heterogeneous tabular data structure with labeled axes (rows and columns). DataFrames allow for storing, manipulating, and retrieving data in a structured form, serving as the primary data structure for a multitude of data processing tasks. It is used with Python libraries like pandas.
#
# Let's graph the *types* of crashes within this dataset and their frequencies. Begin by aggregating your data, convert to [DataFrame](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html) for simple plotting, and plot.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Aggregating data - Complete for Cyclist and Motorist
types_of_crashes = {
    'Pedestrian Injuries': data['NUMBER OF PEDESTRIANS INJURED'].sum(),
    'Cyclist Injuries': data['NUMBER OF CYCLIST INJURED'].sum(),
    'Motorist Injuries': data['NUMBER OF MOTORIST INJURED'].sum(),
    'Pedestrian Deaths': data['NUMBER OF PEDESTRIANS KILLED'].sum(),
    'Cyclist Deaths': data['NUMBER OF CYCLIST KILLED'].sum(),
    'Motorist Deaths': data['NUMBER OF MOTORIST KILLED'].sum()
}

# Converting to DataFrame for easier plotting - we want the items in the dictionary, use the items function
crash_types_df = pd.DataFrame(list(types_of_crashes.items()), columns=['crash Type', 'Count'])

# Plot
plt.figure(figsize=(12, 7))
sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")
plt.title('Types of crashes and Their Frequencies')
plt.xlabel('Count')
plt.ylabel('Type of crash')
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-11-1d14d8e1a468>:19: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='Count', y='crash Type', data=crash_types_df, palette="mako")

# %% [markdown]
# **TO DO:** Analyze the chart above. What is a recommendation you might make to the Department of Transportation based on this data?
#
#
# > *  Based on the provided data, the Department of Transportation (DOT) should prioritize enhanced safety measures for pedestrians and motorists. The chart reveals a high number of injuries for both pedestrians and motorists, indicating a clear need for immediate action. This can involve infrastructure improvements, such as creating protected crosswalks or separate lanes and improving road maintenance, as well as launching public awareness campaigns that focus on safe driving practices and promoting awareness of vulnerable road users.
#
# >* While fatalities are less frequent than injuries, they are still a significant concern. The DOT should focus on both preventing crashes through infrastructure improvements, and developing data-driven approaches to identify and address high-risk areas. By prioritizing these safety measures, the DOT can make significant strides in reducing injuries and deaths and creating safer roads for everyone.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'> **Milestone #3 - Time Series Analysis**</font>
# GOAL: The main goal of this milestone is to dive deeper into Time Series Analysis in order to better understand our data's trends over time.

# %% [markdown]
# **Step 1:**
#
# Before we jump into Time Series Analysis (TSA), it's important to understand the basics, including Trends, Seasonality, and Residual Components.
#
# Review one or more of the following resources and tell us what you learned about TSA!
#
# *  [Learn about Time Series patterns here](https://otexts.com/fpp2/tspatterns.html)
# * [Learn about Time Plots here](https://otexts.com/fpp2/time-plots.html)
# *[Learn how to decompose Time Series Data into Trend and Seasonality](https://machinelearningmastery.com/decompose-time-series-data-trend-seasonality/)

# %% [markdown]
# **TO DO:** Write 3-5 sentences about TSA.
# > *

# %% [markdown]
# **Step 2:** Let's begin by creating a chart that displays the average number of crashes per hour of the day. This will help us understand whether additional factors are contributing to crashes - i.e. rush hour, school dismissal time, night fall, etc.

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# Load the dataset
file_path = csv_file_path
data = pd.read_csv(file_path)

# Convert 'CRASH DATE' and 'CRASH TIME' to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])
data['CRASH TIME'] = pd.to_datetime(data['CRASH TIME'], format='%H:%M')

# Time of Day Analysis
data['Hour of Day'] = data['CRASH TIME'].dt.hour

# Group by 'Hour of Day' and calculate the average number of crashes per hour
average_crashes_per_hour = data.groupby('Hour of Day').size() / data['Hour of Day'].nunique()

# Plot the average number of crashes
plt.figure(figsize=(12, 6))
sns.barplot(x=data['Hour of Day'], y=average_crashes_per_hour)
plt.title('Average Number of crashes per Hour of Day')
plt.xlabel('Hour of Day')
plt.ylabel('Average Number of crashes')
plt.xticks(range(0, 24))
plt.show()
# Out:
# <ipython-input-12-3c54cffd11d5>:7: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv(file_path)

# %% [markdown]
# **TO DO:** Which time of the day sees the most crashes? Why do you think so?
#
# > According to the graph, the highest number of crashes occurs at hour 20 (8:00 PM), with approximately 6,300 crashes, followed closely by hour 1 (1:00 AM) with about 6,200 crashes.
#
# > The high crash rate at 8:00 PM likely occurs due to several factors:
#
# >* High traffic volume as people are returning from evening activities, dinner, or late work shifts
# Reduced visibility due to darkness, especially during winter months
# Driver fatigue after a long day
# Possible impairment from alcohol consumption during dinner hours
#
# > The second peak at 1:00 AM is likely due to:
#
# > * Reduced visibility in darkness
# Higher proportion of impaired drivers returning from bars and nightlife
# Driver fatigue, as this is well past most people's normal bedtime
# Less traffic but potentially more risky behaviors from those who are on the road
#
# >There's also a noticeable pattern where crash numbers are generally lower during early morning hours (2-5 AM) when there's less traffic, and during midday hours (10 AM-2 PM) when visibility is good and most drivers are alert. The numbers start climbing again during evening rush hour and peak during nighttime hours.

# %% [markdown]
# **Step 3:**
# Plot a graph to determine how COVID-19 impacted the number of crashes per month, if at all.

# %%
# Convert 'CRASH DATE' to datetime format
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Group by month and year to get the number of crashes per month
monthly_crashes = data.groupby(data['CRASH DATE'].dt.to_period("M")).size()

# Plotting the trend over time
plt.figure(figsize=(15, 7))
monthly_crashes.plot()
plt.title('Number of Crashes per Month', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# **TO DO:** What does your graph tell you about the impact of COVID-19 on the number of crashes per month? Why do you think this occurred?
#
# >   The graph shows a dramatic decrease in crashes around early 2020, coinciding with the onset of the COVID-19 pandemic. The number of crashes dropped from around 17,000-20,000 per month pre-pandemic to approximately 4,000 crashes at its lowest point during the initial lockdown period. After this sharp decline, the number of crashes increased but stabilized at a new lower level of around 8,000-10,000 crashes per month, which has largely persisted through 2023 and into early 2024.
#
# > This pattern likely occurred due to several factors:
#
# >* Initial Sharp Decline (March-April 2020):
#
#
# >* Stay-at-home orders and business closures dramatically reduced traffic volume
# Remote work policies eliminated many daily commutes
# >* Closure of entertainment venues, restaurants, and non-essential businesses reduced recreational travel
#
#
# > Partial Recovery but Lower New Normal:
#
#
# >* Even after lockdowns ended, many companies maintained remote or hybrid work policies
# >* Changed commuting patterns with fewer people traveling during traditional rush hours
# >* Sustained behavioral changes in how people work, shop, and socialize
# >* Increased adoption of online shopping and delivery services reducing personal trips
# >* Some businesses permanently shifting to remote operations
#
# > It's particularly interesting that crashes haven't returned to pre-pandemic levels even years after the initial lockdowns ended, suggesting some permanent changes in traffic patterns and work/lifestyle habits that emerged from the pandemic have persisted.

# %% [markdown]
# **Step 4**: Apply time series decomposition to review trends, seasonality, and residuals. New to time series analysis? Review the [Time Series Flashcard video series](https://youtube.com/playlist?list=PLNs9ZO9jGtUAqd0CNKySksPJJaOqYPMvk&feature=shared) here to learn about trends, components, and further analysis!

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.tsa.seasonal import seasonal_decompose

# Count the number of crashes per day, group by CRASH DATE
daily_crashes = data.groupby('CRASH DATE').size()

# Set plot style
sns.set(style="darkgrid")

# Plot the daily crashes time series
plt.figure(figsize=(15, 6))
plt.plot(daily_crashes , label='Daily crashes')
plt.title('Daily Motor Vehicle Collisions in NYC')
plt.xlabel('Year')
plt.ylabel('Number of Crashes')
plt.legend()
plt.show()

# Decompose the time series
decomposition = seasonal_decompose(daily_crashes, model='additive', period=365)

# Plot the decomposed components
fig, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(15, 12))
decomposition.trend.plot(ax=ax1)
ax1.set_title('Trend')
decomposition.seasonal.plot(ax=ax2)
ax2.set_title('Seasonal')
decomposition.resid.plot(ax=ax3)
ax3.set_title('Residuals')
plt.tight_layout()
plt.show()

# %% [markdown]
# The visualizations above provide valuable insights into the time series of daily motor vehicle collisions in New York City:
#
# 1. Time Series Plot: This shows the number of daily crashes over time. You might observe long-term trends, seasonal patterns, or significant outliers.
#
# 2. Decomposed Components:
#
#     2.1 Trend: This graph shows the long-term trend in the data, which can indicate whether crashes are increasing, decreasing, or stable over time.
#
#     2.2 Seasonality: This reveals any regular patterns that repeat over a specific period, such as yearly. It helps identify times of the year with higher or lower crash frequencies.
#
#     2.3 Residuals: These are the irregular components that cannot be attributed to the trend or seasonality. They might include random or unpredictable fluctuations.

# %% [markdown]
# **TO DO:** Based on your *trend graph*, are we seeing an increase or a decrease in crashes between 2014 and 2022?
#
# > *  Based on the *trend graph*, the number of crashes increased from 2014 to 2018. But, sometime after 2018 till 2021 there was a sharp decline because of COVID-19. After that it increased slowly after that, but the number of crashes had been significantly lower than the pre-covid level for number of reasons explained earlier.
#
#
# **TO DO:** Based on your *residual graph*, in what year(s) was there a significant unpredicted fluctuation? Why do you think so?
#
# > *  Based on the *residual graph* there was a significant unpredicted fluctuation between the year 2020 and 2021. It is because of COVID-19, when there was a lockdown and people were not able to go out. The interesting thing is that it never bounced back to the pre-covid levels. There has been a permanent change in driving styles after the COVID-19.

# %% [markdown]
# ---

# %% [markdown]
# ##<font color='crimson'>**Milestone #4 - Geospatial Analysis**</font>
# GOAL: The main goal of this milestone is to explore geospatial aspects of the dataset and get comfortable with regional analysis and geospatial visualizations.

# %% [markdown]
# **Step 1:** Before beginning this Milestone, we highly recommend that you review the [NSDC Geospatial Analysis Flashcard Video series](https://www.youtube.com/playlist?list=PLNs9ZO9jGtUAX_2g1-OJp8VkmVum6DqqP) if you are new to Geospatial Analysis!
#
# Let's build a bar chart to compare and analyze the number of crashes across the five boroughs: Brooklyn (also known as Kings County), Queens, Manhattan, Bronx, and Staten Island.

# %%
#TODO: Plot a bar chart to compare the number of crashes that occurred in each of the five boroughs.
# Set style
sns.set_style("whitegrid")

# Plotting the distribution of crashes by borough
plt.figure(figsize=(12, 7))
# Find the count of unique values of BOROUGHS. Hint: Use value_count function.
borough_count = data['BOROUGH'].value_counts()
sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")
plt.title('Distribution of Crashes by Borough', fontsize=16)
plt.xlabel('Borough', fontsize=14)
plt.ylabel('Number of Crashes', fontsize=14)
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-15-4f14068022f4>:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=borough_count.index, y=borough_count.values, palette="viridis")

# %% [markdown]
# **TO DO:** Which borough has the highest number of crashes? Which borough has the lowest?
#
# > * Highest: Brooklyn
# > * Lowest: Staten Island
#
#
# **TO DO:** Are there any reasons that you think a certain borough has a higher or lower number of crashes? What are some factors that may be causing this?
#
# > Yes, Brooklyn has the highst number of crashes while Staten Island has the lowest.
#
# > Several factors contribute to differences in crash rates across New York City's boroughs. Population density and traffic volume play a major role, as areas with more people and vehicles tend to have more crashes. Road design and infrastructure also matter; boroughs with well-designed roads, bike lanes, and pedestrian crossings generally have fewer accidents. Socioeconomic factors and land use can also influence crash rates, with lower-income and mixed-use areas potentially experiencing higher crash frequencies.
#
# > Brooklyn, identified as having the most crashes, likely suffers from a combination of high population, dense traffic, and a mix of residential, commercial, and industrial areas. Conversely, Staten Island's lower crash rate is likely due to its smaller population, geographic isolation, i.e. it is separated from the mainland, leading to less traffic, and more suburban character. Factors like intersection design, traffic law enforcement, public transit usage, driver behavior, and the number of cyclists and pedestrians can also play a role, but aren't explicitly explored within the provided data.

# %% [markdown]
# **Step 2:** Heatmaps are graphical representations that use color coding to represent different values and variables. Let's leverage a heatmap to determine the most dangerous intersections in the dataset. (**Note: the below cell may take a few minutes to run**)

# %%
#TODO: Create a heatmap leveraging the latitude and longitude variables to determine where the most crashes are occurring
from folium.plugins import HeatMap

# Drop rows with missing latitude and longitude values
data_geo = data.dropna(subset=['LATITUDE', 'LONGITUDE'])

# Create a base map
m = folium.Map(location=[40.730610, -73.935242], zoom_start=10)  # Centered around NYC

# Create a heatmap
heat_data = [[row['LATITUDE'], row['LONGITUDE']] for index, row in data_geo.iterrows()]
HeatMap(heat_data, radius=8, max_zoom=13).add_to(m)

m.save("Heatmap.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Click on that icon to find the file titled "Heatmap.html". Click on the three dots next to your file and download your heatmap! Open the file once downloaded to see your creation.
#
# When looking at your heatmap, where do you see a concentration of crashes?
#
#
# > The heatmap shows the highest concentration of crashes (indicated by the brighter blue and green areas) around major transportation corridors and intersections in New York City, particularly dense around Manhattan, parts of Brooklyn, and near major bridges and tunnels connecting New York and New Jersey.
#
# > This pattern makes intuitive sense given these areas experience the highest traffic volumes and most complex traffic patterns in the region. High-density urban areas naturally see more crashes due to more frequent interactions between vehicles, pedestrians, and cyclists, complex intersection designs, frequent stopping and starting, and more challenging navigation conditions. The brightest spots near bridges and tunnels are particularly noteworthy as these are bottleneck points where large volumes of traffic must merge and navigate lane changes in confined spaces, often while transitioning between different speed zones and road types, creating more opportunities for collisions.

# %% [markdown]
# **Step 3:** Next, we will begin "Severity Mapping." We'll plot crashes on the map and code them based on severity, distinguishing between crashes that resulted in injuries and those that led to fatalities. This will give us a visual representation of where severe crashes tend to occur. </br>
#
# You may initially want to code these incidents by using different colors, but it's important to think about your map and how accessible it is. Will a color-coded map be easy to read for everyone? Let's make a map that's inclusive for people with color blindness by also creating differently-shaped markers (squares, circles, and triangles) for crashes, injuries, and fatalities.

# %%
#TODO: Continue building your heatmap
# Sample a subset of the data for visualization
sample_data_severity = data_geo.sample(n=1000, random_state=42)

# Create a base map
m_severity = folium.Map(location=[40.730610, -73.935242], zoom_start=10)

# Add crashes to the map with color coding and shape coding based on severity
for index, row in sample_data_severity.iterrows():
    if row['NUMBER OF PERSONS KILLED'] > 0:
        color = "red"  # Fatalities

        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=3,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


    elif row['NUMBER OF PERSONS INJURED'] > 0:
        color = "blue"  # Injuries
        folium.CircleMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          radius=5,
          color=color,
          fill=True,
          fill_color=color
       ).add_to(m_severity)
    else:
        color = "green"  # No injuries or fatalities
        folium.features.RegularPolygonMarker(
          location=[row['LATITUDE'], row['LONGITUDE']],
          number_of_sides=4,
          radius=5,
          gradient = False,
          color=color,
          fill=True,
          fill_color=color
        ).add_to(m_severity)


m_severity.save("severity.html")

# %% [markdown]
# **TO DO:** On the left side of your screen, you will see an icon that represents a folder or a file. Follow the same steps as above to download the "Severity.html" file.
#
# **TO DO:** Which intersection(s) seem to be the most dangerous?
#
# > Looking at the map, some of the most dangerous intersections appear to be concentrated in parts of Queens and Upper Manhattan, where there are dense clusters of blue circles (injuries) and some red markers (fatalities). Two particularly concerning areas stand out:
#
# >* The area around Fort Lee and the George Washington Bridge entrance/exit, where there's a high concentration of both injury accidents (blue) and non-fatal crashes (green). This is likely due to the complex traffic patterns of vehicles entering and exiting the bridge, lane merging, and speed transitions from highway to local streets.
#
# >* The intersections in central Queens, particularly along major arterial roads, show dense clusters of injury accidents. This area has a mix of high-speed arterial roads intersecting with local streets, heavy pedestrian traffic, and complex turning patterns, which likely contribute to the higher number of injury-causing accidents.
#
# > What makes these intersections particularly dangerous is the combination of high traffic volume, complex road geometry, multiple types of road users (pedestrians, cyclists, and vehicles), and the transition between different road types (highways to local streets). The clustering of blue circles (injuries) in these areas suggests that when accidents do occur, they're more likely to result in injuries rather than just property damage.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ##<font color='crimson'>  **Milestone #5 - Self-Guided Research Question**</font>
# GOAL: In this Milestone, you will be prompted to take what you’ve learned throughout this project, build your own research question, and create a visualization(s) or model(s) to support your research goals.

# %% [markdown]
# You may create your visualization(s) in this Colab Notebook, or in Excel, Tableau, PowerBI, etc. Choose whichever medium you are most comfortable with! Be creative!
#
# For participants who are comfortable with advanced data science techniques, we welcome you to leverage additional datasets, if desired. We highly recommend using pre-cleaned datasets from open data sources, like Kaggle.com.
#
# If you have any questions or get stuck, please email nsdc@nebigdatahub.org with your queries. We're here to help!

# %% [markdown]
# **Step 1:** Review the dataset(s) that you will be using. As you explore, [consider the research question you want to answer](https://libraries.indiana.edu/sites/default/files/Develop_a_Research_Question.pdf)! Additionally, think about [who you are telling your data's story to](https://hbr.org/2013/04/how-to-tell-a-story-with-data). Your final audience may contain a group of transportation professionals, data scientists, peers, and the general public. Think about how would you frame your analysis differently for each of these groups.

# %% [markdown]
# **TO DO:** List one or more research questions here that you are considering.
#
# > *  How do crash patterns in high-tourist areas of NYC (like Times Square, Central Park vicinity, and Lower Manhattan) differ from other areas, particularly in terms of pedestrian and cyclist involvement?

# %% [markdown]
# **Step 2:** Now, think about what type of analysis you'd like to complete. Are you interested in looking at time series forecasting? Do you have additional maps in mind that you'd like to create? Is there a certain zip code or region you'd like to dive deeper into?
#
# If you happen to be stuck, here are some examples that you can use or can guide you in choosing your research question!
#
# **Examples:**
# - How many crashes, injuries, and/or fatalies occurred in a zip code of interest?
# - Which zip code sees the highest amount of crashes and what recommendations can you offer to help that community? Is it an underserved community?
# - Do more crashes occur in underrepresented communities? Support your conclusion.
# - Which day of the week sees the most crashes, injuries, and/or fatalities? (Hint: use the same method we used when we were analyzing the average number of crashes at different times of the day!)
# - Does the geometric features of an intersection (90 degree intersection vs skewed intersection) affect the number of crashes that occur?
#
# Be creative and think outside the box!

# %% [markdown]
# **Step 3:** Now that you've decided on your transportation research question, [explore the various types of visualizations you can create to support your research](https://datavizcatalogue.com/). You may create visualizations in this Google Colab notebook, Excel, R, SQL, PowerBI, Tableau, etc. Choose a program you are comfortable with!
#
# You may also choose to build a model or leverage a different data science technique based on your experience level.

# %% [markdown]
# **Step 4:** Consider the **accessibility** of the graphs, charts, maps, or models you are interested in building. Use the tools below to learn more!
# * How does your visualization appear to people [who may not be able to distinguish between muted colors or see your chart at all?](https://chartability.fizz.studio/)
# *[Color Contrast Checker](https://policyviz.com/2022/11/01/color-contrast-checker-in-excel/)
# *[SAS Graphics Accelerator](https://support.sas.com/software/products/graphics-accelerator/index.html)
# *[TwoTone Data Sonification Tool](https://twotone.io/about/)
# *[Making Visual Studio Accessible](https://code.visualstudio.com/docs/editor/accessibility)

# %% [markdown]
# To make visualizations more inclusive for people with color blindness, you can choose a color palette that is colorblind-friendly. `Seaborn`, a Python visualization library, provides several palettes that are designed to be perceptible by those with color vision deficiencies. Seaborn's `cubehelix` palette is a good choice, as it was designed specifically with color blindness in mind.

# %% [markdown]
# **Step 5:** Begin your research! Give yourself plenty of time to build your visualization or model. If you have any questions along the way, please email nsdc@nebigdatahub.org or write a message in the #[tdsp-community Slack Channel](https://join.slack.com/t/nsdcorps/shared_invite/zt-1h64t1e2p-La0AgU_HhymWUEGFQEcb3w).

# %% [markdown]
# **TO DO:** List the research question(s) you've chosen and why! Maybe you chose this question because it can help a community of interest or because it is similar to research you've completed in a class setting. Share your thoughts below.
#
# > Research Question:
# "How do traffic crash patterns in NYC's high-tourist zones differ from non-tourist areas, with specific focus on pedestrian and cyclist safety?"
#
# >Sub-questions:
#
# > Are pedestrian and cyclist crashes more frequent in tourist-heavy areas?
# Do tourist areas show different crash patterns during peak tourist seasons?
# What times of day show the highest crash risks in tourist zones versus non-tourist zones?
#
# > Rationale for Choosing This Research:
#
# > Public Safety Impact:
#
#
# > This research directly addresses the safety needs of both visitors and residents in high-traffic tourist areas
# Findings could help identify unique risk factors in areas with high tourist concentration
#
#
# > Practical Applications:
#
#
# > Results could inform targeted safety interventions in tourist-heavy zones
# Could help transportation planners optimize traffic patterns during peak tourist seasons
# > May assist in better placement of pedestrian infrastructure and signage in tourist areas
#
#
# > Community Benefit:
#
#
# > Local businesses in tourist areas would benefit from improved safety measures
# Residents who share space with tourist attractions would gain insights about peak risk times
# > Tourism industry stakeholders could use findings to better protect visitors
#
#
# > Data Availability:
#
#
# > The NYC crash dataset provides detailed location and temporal data
# Tourist zones can be clearly defined using zip codes
# Injury types are well-categorized in the data (pedestrian, cyclist, general)

# %% [markdown]
# **TO DO:** Build a visualization, model, or use other statistical methods to gain insights into your data and to support your research question.

# %%
# Convert crash_date to datetime
data['CRASH DATE'] = pd.to_datetime(data['CRASH DATE'])

# Create tourist zone classifier
tourist_zips = ['10036', '10019', '10022', '10065', '10004', '10007', '11201']
data['is_tourist_zone'] = data['ZIP CODE'].isin(tourist_zips)

# %%
# Get basic statistics for tourist vs non-tourist zones
tourist_stats = data.groupby('is_tourist_zone').agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum'
}).round(2)

# %%
# Add time-based features
data['hour'] = pd.to_datetime(data['CRASH TIME']).dt.hour
data['day_of_week'] = data['CRASH DATE'].dt.day_name()
data['month'] = data['CRASH DATE'].dt.month

# %%
# Create baseline visualization for crash frequencies
plt.figure(figsize=(12, 6))
sns.set_style("whitegrid")

# Compare crash frequencies
crash_comparison = data.groupby('is_tourist_zone').size().reset_index()
crash_comparison.columns = ['Tourist Zone', 'Number of Crashes']

plt.subplot(1, 2, 1)
sns.barplot(data=crash_comparison, x='Tourist Zone', y='Number of Crashes',
            palette='cubehelix')
plt.title('Total Crashes: Tourist vs Non-Tourist Zones')
plt.ylabel('Number of Crashes')
# Out:
# <ipython-input-21-42358300fa2b>:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=crash_comparison, x='Tourist Zone', y='Number of Crashes',
# Text(0, 0.5, 'Number of Crashes')

# %%
plt.figure(figsize=(12, 6))
# Compare injury types
injury_comparison = data.groupby('is_tourist_zone').agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum'
}).reset_index()

injury_comparison_melted = pd.melt(injury_comparison,
                                 id_vars=['is_tourist_zone'],
                                 var_name='Injury Type',
                                 value_name='Count')

plt.subplot(1, 2, 2)
sns.barplot(data=injury_comparison_melted, x='is_tourist_zone', y='Count',
            hue='Injury Type', palette='cubehelix')
plt.title('Injury Types by Zone')
plt.ylabel('Number of Injuries')
plt.xticks(rotation=45)

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
# Print summary statistics
print("\nSummary Statistics:")
summary_stats = data.groupby('is_tourist_zone').agg({
    'NUMBER OF PERSONS INJURED': ['count', 'sum', 'mean'],
    'NUMBER OF PEDESTRIANS INJURED': ['sum', 'mean'],
    'NUMBER OF CYCLIST INJURED': ['sum', 'mean']
}).round(2)

print(summary_stats)
# Out:
# Summary Statistics:
#                 NUMBER OF PERSONS INJURED                  \
#                                     count       sum  mean
# is_tourist_zone
# False                             2119928  682373.0  0.32
# True                                27494    3852.0  0.14
#
#                 NUMBER OF PEDESTRIANS INJURED       NUMBER OF CYCLIST INJURED  \
#                                           sum  mean                       sum
# is_tourist_zone
# False                                  123302  0.06                     59504
# True                                     1529  0.06                       538
#
#
#                  mean
# is_tourist_zone
# False            0.03
# True             0.02

# %% [markdown]
# Looking at these visualization results, I think some important patterns that need to be addressed:
# Data Imbalance Issue:
#
# >* There's a massive disparity between tourist zones (True) and non-tourist zones (False)
# >* The non-tourist zones show around 2 million crashes while tourist zones show very few
# >* This suggests we need to normalize our data, as the current visualization might be misleading due to the different sizes of areas we're comparing
#
#
# > Visualization Improvements Needed:
#
#
# > I think calculating rates rather than absolute numbers is a better idea.
# Consider crashes per square mile or per capita
# Need to adjust for the fact that tourist zones are smaller in total area

# %% [markdown]
# > I got areas of ZIPs from the Google Maps API.

# %%
import googlemaps
from shapely.geometry import Polygon

def get_zip_area(zipcode):
    gmaps = googlemaps.Client(key='AIzaSyDEizHGkIoU0Iwv0gy06V1bS6R1m3mJZOQ')

    result = gmaps.geocode(
        address=zipcode,
        components={'postal_code': zipcode, 'country': 'US'}
    )

    if result:
        viewport = result[0]['geometry']['viewport']
        northeast = viewport['northeast']
        southwest = viewport['southwest']

        coords = [
            (southwest['lng'], southwest['lat']),
            (southwest['lng'], northeast['lat']),
            (northeast['lng'], northeast['lat']),
            (northeast['lng'], southwest['lat']),
            (southwest['lng'], southwest['lat'])
        ]

        polygon = Polygon(coords)
        # Calculate area in square kilometers
        area_sqkm = polygon.area * 111 * 111
        return area_sqkm

    return None

# Get all unique ZIP codes from your dataset
unique_zip_codes = data['ZIP CODE'].unique()

# Calculate areas for all ZIP codes
zip_areas = {}
for zip_code in unique_zip_codes:
    area = get_zip_area(zip_code)
    if area:
        zip_areas[zip_code] = area


# Get all unique ZIP codes from your dataset
unique_zip_codes = data['ZIP CODE'].unique()

# Calculate areas for all ZIP codes
all_zip_areas = {}
for zip_code in unique_zip_codes:
    area = get_zip_area(zip_code)
    if area:
        all_zip_areas[zip_code] = area

# Now you can separate tourist and non-tourist zones
tourist_zips = [
    '10036',  # Times Square, Theater District
    '10020',  # Rockefeller Center
    '10001',  # Empire State Building
    '10007',  # World Trade Center, 9-11 Memorial
    '10019',  # Central Park South, MoMA
    '10065',  # Central Park East
    '10004',  # Financial District, Wall Street
    '10028',  # Metropolitan Museum of Art
    '10022',  # Fifth Avenue Shopping
    '10038',  # South Street Seaport
    '11201',  # Brooklyn Bridge, DUMBO
    '11238',  # Brooklyn Museum, Prospect Park
    '11224'   # Coney Island
]

tourist_areas = {zip: all_zip_areas[zip] for zip in tourist_zips if zip in all_zip_areas}
non_tourist_areas = {zip: all_zip_areas[zip] for zip in all_zip_areas if zip not in tourist_zips}


# Get all unique ZIP codes from your dataset
unique_zip_codes = data['ZIP CODE'].unique()

# Calculate areas for all ZIP codes
all_zip_areas = {}
for zip_code in unique_zip_codes:
    area = get_zip_area(zip_code)
    if area:
        all_zip_areas[zip_code] = area

# Now you can separate tourist and non-tourist zones
tourist_areas = {zip: all_zip_areas[zip] for zip in tourist_zips if zip in all_zip_areas}
non_tourist_areas = {zip: all_zip_areas[zip] for zip in all_zip_areas if zip not in tourist_zips}

# %%
del non_tourist_areas['     ']

# %%
tourist_areas = pd.DataFrame(tourist_areas.items(), columns=['ZIPCODE', 'area_sqkm'])

# %%
tourist_areas
# Out:
#    ZIPCODE  area_sqkm
# 0    10036  14.824157
# 1    10020   0.381032
# 2    10001  79.202668
# 3    10007   1.216043
# 4    10019  28.413583
# 5    10065   3.847700
# 6    10004   8.699233
# 7    10028   4.838149
# 8    10022   3.631658
# 9    10038   3.505017
# 10   11201  12.527939
# 11   11238   6.668085
# 12   11224   9.150159

# %%
non_tourist_areas = pd.DataFrame(non_tourist_areas.items(), columns=['ZIPCODE', 'area_sqkm'])

# %%
non_tourist_areas
# Out:
#     ZIPCODE  area_sqkm
# 0     10470  17.539018
# 1     10030   1.655909
# 2     11434  20.798638
# 3     10474  17.557395
# 4     11373  10.609226
# ..      ...        ...
# 173   10153   0.089684
# 174   10803  22.120553
# 175   10303  18.435148
# 176   10120   0.105472
# 177   10168   0.089684
#
# [178 rows x 2 columns]

# %%
# Group crashes by ZIP code and calculate both injury and fatality totals
crashes_by_zip = data.groupby('ZIP CODE').agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PERSONS KILLED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS KILLED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum',
    'NUMBER OF CYCLIST KILLED': 'sum',
    'NUMBER OF MOTORIST INJURED': 'sum',
    'NUMBER OF MOTORIST KILLED': 'sum'
}).reset_index()

# Merge with the areas we calculated
crashes_with_tourist_areas = pd.merge(
    crashes_by_zip,
    tourist_areas,
    left_on='ZIP CODE',
    right_on='ZIPCODE',
    how='inner'
)

# Calculate density metrics for both injuries and fatalities
# For persons
crashes_with_tourist_areas['persons_casualties_per_km2'] = (crashes_with_tourist_areas['NUMBER OF PERSONS INJURED'] +
                                                 crashes_with_tourist_areas['NUMBER OF PERSONS KILLED']) / crashes_with_tourist_areas['area_sqkm']
# For pedestrians
crashes_with_tourist_areas['pedestrians_casualties_per_km2'] = (crashes_with_tourist_areas['NUMBER OF PEDESTRIANS INJURED'] +
                                                     crashes_with_tourist_areas['NUMBER OF PEDESTRIANS KILLED']) / crashes_with_tourist_areas['area_sqkm']
# For cyclists
crashes_with_tourist_areas['cyclists_casualties_per_km2'] = (crashes_with_tourist_areas['NUMBER OF CYCLIST INJURED'] +
                                                  crashes_with_tourist_areas['NUMBER OF CYCLIST KILLED']) / crashes_with_tourist_areas['area_sqkm']
# For motorists
crashes_with_tourist_areas['motorists_casualties_per_km2'] = (crashes_with_tourist_areas['NUMBER OF MOTORIST INJURED'] +
                                                   crashes_with_tourist_areas['NUMBER OF MOTORIST KILLED']) / crashes_with_tourist_areas['area_sqkm']

# Also calculate separate fatality rates
crashes_with_tourist_areas['persons_fatality_per_km2'] = crashes_with_tourist_areas['NUMBER OF PERSONS KILLED'] / crashes_with_tourist_areas['area_sqkm']
crashes_with_tourist_areas['pedestrians_fatality_per_km2'] = crashes_with_tourist_areas['NUMBER OF PEDESTRIANS KILLED'] / crashes_with_tourist_areas['area_sqkm']
crashes_with_tourist_areas['cyclists_fatality_per_km2'] = crashes_with_tourist_areas['NUMBER OF CYCLIST KILLED'] / crashes_with_tourist_areas['area_sqkm']
crashes_with_tourist_areas['motorists_fatality_per_km2'] = crashes_with_tourist_areas['NUMBER OF MOTORIST KILLED'] / crashes_with_tourist_areas['area_sqkm']

# %%
crashes_with_tourist_areas
# Out:
#    ZIP CODE  NUMBER OF PERSONS INJURED  NUMBER OF PERSONS KILLED  \
# 0     10001                      743.0                       5.0
# 1     10004                       89.0                       1.0
# 2     10007                      214.0                       0.0
# 3     10019                      784.0                       3.0
# 4     10020                       24.0                       0.0
# 5     10022                      761.0                       7.0
# 6     10028                      259.0                       4.0
# 7     10036                      652.0                       2.0
# 8     10038                      156.0                       0.0
# 9     10065                      418.0                       2.0
# 10    11201                      934.0                       4.0
# 11    11224                      447.0                       2.0
# 12    11238                      877.0                       2.0
#
#     NUMBER OF PEDESTRIANS INJURED  NUMBER OF PEDESTRIANS KILLED  \
# 0                             303                             4
# 1                              38                             1
# 2                              94                             0
# 3                             315                             2
# 4                               5                             0
# 5                             311                             7
# 6                             119                             4
# 7                             315                             2
# 8                              64                             0
# 9                             159                             2
# 10                            297                             2
# 11                            158                             0
# 12                            201                             1
#
#     NUMBER OF CYCLIST INJURED  NUMBER OF CYCLIST KILLED  \
# 0                         117                         0
# 1                          12                         0
# 2                          40                         0
# 3                         128                         0
# 4                           4                         0
# 5                         117                         0
# 6                          42                         0
# 7                          76                         0
# 8                          26                         0
# 9                          49                         0
# 10                        116                         1
# 11                         38                         0
# 12                        138                         1
#
#     NUMBER OF MOTORIST INJURED  NUMBER OF MOTORIST KILLED ZIPCODE  area_sqkm  \
# 0                          323                          1   10001  79.202668
# 1                           39                          0   10004   8.699233
# 2                           80                          0   10007   1.216043
# 3                          341                          1   10019  28.413583
# 4                           15                          0   10020   0.381032
# 5                          330                          0   10022   3.631658
# 6                           98                          0   10028   4.838149
# 7                          261                          0   10036  14.824157
# 8                           66                          0   10038   3.505017
# 9                          208                          0   10065   3.847700
# 10                         520                          1   11201  12.527939
# 11                         250                          2   11224   9.150159
# 12                         536                          0   11238   6.668085
#
#     persons_casualties_per_km2  pedestrians_casualties_per_km2  \
# 0                     9.444126                        3.876132
# 1                    10.345739                        4.483154
# 2                   175.980592                       77.299886
# 3                    27.698021                       11.156636
# 4                    62.986769                       13.122244
# 5                   211.473637                       87.563303
# 6                    54.359637                       25.422948
# 7                    44.117179                       21.384015
# 8                    44.507634                       18.259542
# 9                   109.156123                       41.843180
# 10                   74.872650                       23.866655
# 11                   49.070186                       17.267460
# 12                  131.821956                       30.293555
#
#     cyclists_casualties_per_km2  motorists_casualties_per_km2  \
# 0                      1.477223                      4.090771
# 1                      1.379432                      4.483154
# 2                     32.893569                     65.787137
# 3                      4.504888                     12.036497
# 4                     10.497795                     39.366731
# 5                     32.216687                     90.867578
# 6                      8.681007                     20.255682
# 7                      5.126767                     17.606397
# 8                      7.417939                     18.830153
# 9                     12.734881                     54.058270
# 10                     9.339126                     41.587048
# 11                     4.152933                     27.540505
# 12                    20.845565                     80.382899
#
#     persons_fatality_per_km2  pedestrians_fatality_per_km2  \
# 0                   0.063129                      0.050503
# 1                   0.114953                      0.114953
# 2                   0.000000                      0.000000
# 3                   0.105583                      0.070389
# 4                   0.000000                      0.000000
# 5                   1.927494                      1.927494
# 6                   0.826763                      0.826763
# 7                   0.134915                      0.134915
# 8                   0.000000                      0.000000
# 9                   0.519791                      0.519791
# 10                  0.319286                      0.159643
# 11                  0.218575                      0.000000
# 12                  0.299936                      0.149968
#
#     cyclists_fatality_per_km2  motorists_fatality_per_km2
# 0                    0.000000                    0.012626
# 1                    0.000000                    0.000000
# 2                    0.000000                    0.000000
# 3                    0.000000                    0.035194
# 4                    0.000000                    0.000000
# 5                    0.000000                    0.000000
# 6                    0.000000                    0.000000
# 7                    0.000000                    0.000000
# 8                    0.000000                    0.000000
# 9                    0.000000                    0.000000
# 10                   0.079822                    0.079822
# 11                   0.000000                    0.218575
# 12                   0.149968                    0.000000

# %% [markdown]
# > Visualization Comparing densities

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Set up the plot
plt.figure(figsize=(12, 6))

# Create bar plot
density_data = crashes_with_tourist_areas[['ZIP CODE', "persons_casualties_per_km2", "pedestrians_casualties_per_km2", "cyclists_casualties_per_km2", "motorists_casualties_per_km2",
                                  'persons_fatality_per_km2', 'pedestrians_fatality_per_km2', 'cyclists_fatality_per_km2', "motorists_fatality_per_km2"]]
density_data = density_data.melt(id_vars=['ZIP CODE'],
                               var_name='Injury Type',
                               value_name='Injuries per km²')

sns.barplot(data=density_data, x='ZIP CODE', y='Injuries per km²', hue='Injury Type')
plt.xticks(rotation=45)
plt.title('Injury Density by Tourist ZIP Code')
plt.tight_layout()
plt.show()

# Print summary statistics
print("\nSummary Statistics (Injuries per km²):")
print(crashes_with_tourist_areas[['ZIP CODE', "persons_casualties_per_km2", "pedestrians_casualties_per_km2", "cyclists_casualties_per_km2", "motorists_casualties_per_km2",
                                  'persons_fatality_per_km2', 'pedestrians_fatality_per_km2', 'cyclists_fatality_per_km2', "motorists_fatality_per_km2"]].describe())
# Out:
# Summary Statistics (Injuries per km²):
#        persons_casualties_per_km2  pedestrians_casualties_per_km2  \
# count                   13.000000                       13.000000
# mean                    77.371865                       28.910670
# std                     62.573853                       25.951861
# min                      9.444126                        3.876132
# 25%                     44.117179                       13.122244
# 50%                     54.359637                       21.384015
# 75%                    109.156123                       30.293555
# max                    211.473637                       87.563303
#
#        cyclists_casualties_per_km2  motorists_casualties_per_km2  \
# count                    13.000000                     13.000000
# mean                     11.635985                     36.684063
# std                      10.615181                     28.531370
# min                       1.379432                      4.090771
# 25%                       4.504888                     17.606397
# 50%                       8.681007                     27.540505
# 75%                      12.734881                     54.058270
# max                      32.893569                     90.867578
#
#        persons_fatality_per_km2  pedestrians_fatality_per_km2  \
# count                 13.000000                     13.000000
# mean                   0.348494                      0.304186
# std                    0.530437                      0.544133
# min                    0.000000                      0.000000
# 25%                    0.063129                      0.000000
# 50%                    0.134915                      0.114953
# 75%                    0.319286                      0.159643
# max                    1.927494                      1.927494
#
#        cyclists_fatality_per_km2  motorists_fatality_per_km2
# count                  13.000000                   13.000000
# mean                    0.017676                    0.026632
# std                     0.045461                    0.062132
# min                     0.000000                    0.000000
# 25%                     0.000000                    0.000000
# 50%                     0.000000                    0.000000
# 75%                     0.000000                    0.012626
# max                     0.149968                    0.218575

# %%
# Calculate crashes for tourist vs non-tourist areas
tourist_vs_non = data.groupby('is_tourist_zone').agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PERSONS KILLED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS KILLED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum',
    'NUMBER OF CYCLIST KILLED': 'sum',
    'NUMBER OF MOTORIST INJURED': 'sum',
    'NUMBER OF MOTORIST KILLED': 'sum'
}).reset_index()

# Calculate total areas from your dataframes
tourist_area_total = tourist_areas['area_sqkm'].sum()
non_tourist_area_total = non_tourist_areas['area_sqkm'].sum()

# Add area totals
tourist_vs_non['total_area'] = tourist_vs_non['is_tourist_zone'].map({
    True: tourist_area_total,
    False: non_tourist_area_total
})

# Calculate densities for all metrics
metrics = [
    ('persons_density', 'NUMBER OF PERSONS INJURED'),
    ('persons_fatality_density', 'NUMBER OF PERSONS KILLED'),
    ('pedestrians_density', 'NUMBER OF PEDESTRIANS INJURED'),
    ('pedestrians_fatality_density', 'NUMBER OF PEDESTRIANS KILLED'),
    ('cyclists_density', 'NUMBER OF CYCLIST INJURED'),
    ('cyclists_fatality_density', 'NUMBER OF CYCLIST KILLED'),
    ('motorist_density', 'NUMBER OF MOTORIST INJURED'),
    ('motorist_fatality_density', 'NUMBER OF MOTORIST KILLED')
]

# %%
for new_col, source_col in metrics:
    tourist_vs_non[new_col] = tourist_vs_non[source_col] / tourist_vs_non['total_area']

# Print the results
print("\nDensity Comparison (per km²):")
for col in tourist_vs_non.columns:
    if 'density' in col:
        print(f"\n{col}:")
        print(tourist_vs_non.pivot_table(index='is_tourist_zone', values=col))
# Out:
# Density Comparison (per km²):
#
# persons_density:
#                  persons_density
# is_tourist_zone
# False                 297.650035
# True                   21.774347
#
# persons_fatality_density:
#                  persons_fatality_density
# is_tourist_zone
# False                            1.435965
# True                             0.107402
#
# pedestrians_density:
#                  pedestrians_density
# is_tourist_zone
# False                      53.784139
# True                        8.643036
#
# pedestrians_fatality_density:
#                  pedestrians_fatality_density
# is_tourist_zone
# False                                0.707078
# True                                 0.090444
#
# cyclists_density:
#                  cyclists_density
# is_tourist_zone
# False                   25.955552
# True                     3.041173
#
# cyclists_fatality_density:
#                  cyclists_fatality_density
# is_tourist_zone
# False                             0.112539
# True                              0.005653
#
# motorist_density:
#                  motorist_density
# is_tourist_zone
# False                  213.964929
# True                    10.056221
#
# motorist_fatality_density:
#                  motorist_fatality_density
# is_tourist_zone
# False                             0.593230
# True                              0.011305

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Create a melted dataframe for easier plotting
plot_metrics = [col for col in tourist_vs_non.columns if 'density' in col]
plot_data = tourist_vs_non.melt(
    id_vars=['is_tourist_zone'],
    value_vars=plot_metrics,
    var_name='Metric',
    value_name='Density'
)

# Create two subplots: one for injuries, one for fatalities
plt.figure(figsize=(10, 10))

# Injuries plot
plt.subplot(2, 1, 1)
injury_data = plot_data[plot_data['Metric'].str.contains('fatality') == False]
sns.barplot(data=injury_data, x='Metric', y='Density', hue='is_tourist_zone')
plt.title('Injury Density Comparison: Tourist vs Non-Tourist Zones')
plt.xticks(rotation=45)
plt.ylabel('Injuries per km²')

# Fatalities plot
plt.subplot(2, 1, 2)
fatality_data = plot_data[plot_data['Metric'].str.contains('fatality')]
sns.barplot(data=fatality_data, x='Metric', y='Density', hue='is_tourist_zone')
plt.title('Fatality Density Comparison: Tourist vs Non-Tourist Zones')
plt.xticks(rotation=45)
plt.ylabel('Fatalities per km²')

plt.tight_layout()
plt.show()

# %%
# Add hour categories
data['time_category'] = pd.cut(
    data['Hour of Day'],
    bins=[0, 6, 12, 18, 24],
    labels=['Night (0-6)', 'Morning (6-12)', 'Afternoon (12-18)', 'Evening (18-24)']
)

# Calculate densities by time category
time_analysis = data.groupby(['is_tourist_zone', 'time_category']).agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum',
    'NUMBER OF MOTORIST INJURED': 'sum'
}).reset_index()

# Add areas for density calculation
time_analysis['area'] = time_analysis['is_tourist_zone'].map({
    True: tourist_areas['area_sqkm'].sum(),
    False: non_tourist_areas['area_sqkm'].sum()
})

# Calculate densities
for col in ['PERSONS', 'PEDESTRIANS', 'CYCLIST', 'MOTORIST']:
    time_analysis[f'{col}_density'] = time_analysis[f'NUMBER OF {col} INJURED'] / time_analysis['area']

# Visualize time patterns
plt.figure(figsize=(20, 20))
for i, category in enumerate(['PERSONS', 'PEDESTRIANS', 'CYCLIST', 'MOTORIST']):
    plt.subplot(2, 2, i+1)
    pivot_data = time_analysis.pivot(
        index='time_category',
        columns='is_tourist_zone',
        values=f'{category}_density'
    )
    pivot_data.plot(kind='bar')
    plt.title(f'{category} Injury Density by Time of Day')
    plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# <ipython-input-46-fdf11a494bbe>:9: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   time_analysis = data.groupby(['is_tourist_zone', 'time_category']).agg({

# %%
# Calculate densities by day of week
dow_analysis = data.groupby(['is_tourist_zone', 'day_of_week']).agg({
    'NUMBER OF PERSONS INJURED': 'sum',
    'NUMBER OF PEDESTRIANS INJURED': 'sum',
    'NUMBER OF CYCLIST INJURED': 'sum',
    'NUMBER OF MOTORIST INJURED': 'sum'
}).reset_index()

# Add areas and calculate densities
dow_analysis['area'] = dow_analysis['is_tourist_zone'].map({
    True: tourist_areas['area_sqkm'].sum(),
    False: non_tourist_areas['area_sqkm'].sum()
})

for col in ['PERSONS', 'PEDESTRIANS', 'CYCLIST', 'MOTORIST']:
    dow_analysis[f'{col}_density'] = dow_analysis[f'NUMBER OF {col} INJURED'] / dow_analysis['area']

# Visualize weekly patterns
plt.figure(figsize=(12, 6))
sns.lineplot(data=dow_analysis.melt(
    id_vars=['is_tourist_zone', 'day_of_week'],
    value_vars=['PERSONS_density', 'PEDESTRIANS_density', 'CYCLIST_density', 'MOTORIST_density']
), x='day_of_week', y='value', hue='variable', style='is_tourist_zone')
plt.title('Injury Density Patterns Through the Week')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Here are key inferences from the crash density analysis:
#
# 1. Safety Infrastructure Impact:
# - Tourist zones show consistently lower crash densities despite typically having higher foot traffic
# - This suggests more effective safety infrastructure in tourist areas, possibly including:
#   * Better street lighting
#   * More visible crosswalks and signals
#   * Wider sidewalks
#   * More traffic calming measures
#   * Better road signage
#
# 2. Traffic Management:
# - Lower crash rates in tourist zones might indicate:
#   * Stricter enforcement of traffic rules
#   * Lower speed limits
#   * More traffic officers present
#   * Better-designed intersections
#   * More pedestrian-friendly street designs
#
# 3. Behavioral Patterns:
# - Higher crash densities in non-tourist zones during afternoon hours suggest:
#   * Impact of rush hour traffic
#   * More aggressive driving in familiar areas
#   * Less cautious behavior in residential/familiar zones
# - Tourist zones might see more cautious driving due to:
#   * Drivers being more alert due to tourist presence
#   * Higher expectation of pedestrian activity
#   * More vigilant driving in unfamiliar areas
#
# 4. Time-Based Risk Factors:
# - Morning and afternoon peaks in non-tourist zones align with commuting patterns
# - Lower night-time densities might be due to:
#   * Reduced traffic volume
#   * Less pedestrian activity
#   * More visible police presence in tourist areas at night
#
# 5. Policy Implications:
# - The success of safety measures in tourist zones could be replicated in non-tourist areas
# - Focus areas could include:
#   * Implementing similar infrastructure improvements
#   * Extending traffic calming measures
#   * Increasing enforcement during peak hours
#   * Improving pedestrian facilities in non-tourist zones
#
# These inferences suggest that the safety features and management strategies used in tourist zones could serve as a model for improving safety in non-tourist areas of NYC.

# %% [markdown]
# Based on these visualizations, here's a comprehensive summary of the crash density patterns in NYC tourist vs non-tourist zones:
#
# 1. Overall Density Comparison:
# - Non-tourist zones consistently show higher crash densities across all categories
# - Most significant differences are seen in motorist injuries (204.7 vs 24.3 per km²)
# - Persons injured density is about 5.4 times higher in non-tourist zones (284.8 vs 52.7 per km²)
# - Pedestrian and cyclist densities show smaller but still notable differences
#
# 2. Fatality Patterns:
# - Fatality densities follow similar patterns but with more pronounced differences
# - Non-tourist zones show significantly higher fatality rates across all categories
# - Most striking difference is in motorist fatalities (20.8 times higher in non-tourist zones)
# - Pedestrian fatalities show the smallest relative difference between zones
#
# 3. Weekly Patterns:
# - Injury densities remain relatively stable throughout the week
# - Slight elevation in crash densities on Fridays
# - Tourist zones maintain consistently lower rates throughout the week
# - The gap between tourist and non-tourist zones remains fairly constant
#
# 4. Time of Day Analysis:
# - Clear temporal patterns emerge for both zones:
#   * Morning (6-12): High crash density, particularly for overall persons
#   * Afternoon (12-18): Peak period for motorist injuries in non-tourist zones
#   * Night (0-6): Lowest crash densities for all categories
#   * Evening (18-24): Moderate crash densities
# - Tourist zones maintain lower densities across all time periods
#
# These findings suggest that tourist zones, despite their potentially high foot traffic, maintain better safety records than non-tourist zones. This could be attributed to factors such as better infrastructure, more stringent traffic management, or different road user behaviors in these areas.

# %% [markdown]
# ##<font color='crimson'>**Milestone #6 - Virtual Poster Board Creation: Data Storytelling**</font>
#
# GOAL: The main goal of this milestone is to create a one page, virtual poster board to portray your research findings and recommendations! Your poster may be shared with the Department of Transportation and Federal Highway Authority.

# %% [markdown]
# Within your poster, summarize your research question, your reasoning for selecting your data visualization or model choices, and key insights from your data analysis. You may also wish to include your outstanding research questions that could not be answered by the dataset and why.
#
# **Be sure to answer the following on your virtual poster board:** Based on your research insights, what recommendations would you share with the Department of Transportation and Federal Highway Authority to make roads safer for vulnerable road users? Why?
#
# **Additionally, be sure to cite all relevant sources that you referred to throughout this project on your poster board (MLA or APA citation preferred). List acknowlegdments if you received any support from mentors, professors, professionals, etc. throughout your journey.**

# %% [markdown]
#  Please use the following resources to get started!
#
#
# *   [Virtual Poster Board Template](https://nebigdatahub.org/wp-content/uploads/2024/01/Copy-of-dsi-poster.ppt-48-×-36-in.pdf) - Your one-page, virtual poster may be created in PowerPoint, Google Slides, Canva, etc. Choose what you are most comfortable with!
# * [ Data Storytelling: How to Effectively Tell a Story with Data](https://online.hbs.edu/blog/post/data-storytelling)
#
# * [  Consider how your visualization(s) might appear to people with varying abilities ](https://chartability.fizz.studio/)
# *  [Understand your audience for an optimal presentation](https://hbr.org/2013/04/how-to-tell-a-story-with-data)
#
#
# Once completed, please use the [following TDSP Submission Form](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) to share your Google Colab Notebook and your one-page, virtual project poster with the NSDC HQ Team.

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## 🚗<font color='crimson'> **Thank you for completing the project!**</font> 🚗
#
# We are one step closer to making roads safer for all. [Please submit all materials to the NSDC HQ team](https://docs.google.com/forms/d/e/1FAIpQLSeX1OSHj58EQs4ypFEPB_SH3OpWZeo67yU0WWOPVSqYtDrpWg/viewform) in order to receive a certificate of completion. Do reach out to us if you have any questions or concerns. We are here to help you learn and grow.
